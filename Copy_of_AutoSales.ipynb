# %% [markdown]
# <a href="https://colab.research.google.com/github/Takele2021/powerbi-desktop-samples/blob/main/Copy_of_AutoSales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data"

# %%
df = pd.read_csv(url, header= None)

# %%
df.describe(include = "all")
# Out:
#                 0    1       2    3    4     5      6    7      8   \
# count   205.000000  205     205  205  205   205    205  205    205
# unique         NaN   52      22    2    2     3      5    3      2
# top            NaN    ?  toyota  gas  std  four  sedan  fwd  front
# freq           NaN   41      32  185  168   114     96  120    202
# mean      0.834146  NaN     NaN  NaN  NaN   NaN    NaN  NaN    NaN
# std       1.245307  NaN     NaN  NaN  NaN   NaN    NaN  NaN    NaN
# min      -2.000000  NaN     NaN  NaN  NaN   NaN    NaN  NaN    NaN
# 25%       0.000000  NaN     NaN  NaN  NaN   NaN    NaN  NaN    NaN
# 50%       1.000000  NaN     NaN  NaN  NaN   NaN    NaN  NaN    NaN
# 75%       2.000000  NaN     NaN  NaN  NaN   NaN    NaN  NaN    NaN
# max       3.000000  NaN     NaN  NaN  NaN   NaN    NaN  NaN    NaN
#
#                 9   ...          16    17    18    19          20   21    22  \
# count   205.000000  ...  205.000000   205   205   205  205.000000  205   205
# ...

# %%
header  = ["Symboling", "Normalized-Loses", "Make", "Fuel-Type", "Aspiration", "No-of-doors", "Body Style", "Drive-Wheel", "Engine-Location", "Wheel-Base"
           , "Lenght", "Width", "Height", "Curb-Weight", "Engine-Type", "Num-of-cylinders", "Engine-Size", "Fuel-System", "Bore", "Stroke", "Compression-Ratio"
           , "Horse-Power", "Peak-RPM", "City-MPG", "Highway-MPG","Price"]

# %%
df.columns = header
df.describe(include = "all")
# Out:
#          Symboling Normalized-Loses    Make Fuel-Type Aspiration No-of-doors  \
# count   205.000000              205     205       205        205         205
# unique         NaN               52      22         2          2           3
# top            NaN                ?  toyota       gas        std        four
# freq           NaN               41      32       185        168         114
# mean      0.834146              NaN     NaN       NaN        NaN         NaN
# std       1.245307              NaN     NaN       NaN        NaN         NaN
# min      -2.000000              NaN     NaN       NaN        NaN         NaN
# 25%       0.000000              NaN     NaN       NaN        NaN         NaN
# 50%       1.000000              NaN     NaN       NaN        NaN         NaN
# 75%       2.000000              NaN     NaN       NaN        NaN         NaN
# max       3.000000              NaN     NaN       NaN        NaN         NaN
#
# ...

# %%
path = "/content/Practice/takele.xlsx"

# %%
df.to_excel(path)

# %%
df['Fuel-Type']
# Out:
# 0         gas
# 1         gas
# 2         gas
# 3         gas
# 4         gas
#         ...
# 200       gas
# 201       gas
# 202       gas
# 203    diesel
# 204       gas
# Name: Fuel-Type, Length: 205, dtype: object

# %%
# !head df
# Out:
# head: cannot open 'df' for reading: No such file or directory

# %%
path = "/content/Practice/takele.csv"
df.to_csv(path)

# %%
# !head "/content/Practice/takele.csv"
# Out:
# ,Symboling,Normalized-Loses,Make,Fuel-Type,Aspiration,No-of-doors,Body Style,Drive-Wheel,Engine-Location,Wheel-Base,Lenght,Width,Height,Curb-Weight,Engine-Type,Num-of-cylinders,Engine-Size,Fuel-System,Bore,Stroke,Compression-Ratio,Horse-Power,Peak-RPM,City-MPG,Highway-MPG,Price
# 0,3,?,alfa-romero,gas,std,two,convertible,rwd,front,88.6,168.8,64.1,48.8,2548,dohc,four,130,mpfi,3.47,2.68,9.0,111,5000,21,27,13495
# 1,3,?,alfa-romero,gas,std,two,convertible,rwd,front,88.6,168.8,64.1,48.8,2548,dohc,four,130,mpfi,3.47,2.68,9.0,111,5000,21,27,16500
# 2,1,?,alfa-romero,gas,std,two,hatchback,rwd,front,94.5,171.2,65.5,52.4,2823,ohcv,six,152,mpfi,2.68,3.47,9.0,154,5000,19,26,16500
# 3,2,164,audi,gas,std,four,sedan,fwd,front,99.8,176.6,66.2,54.3,2337,ohc,four,109,mpfi,3.19,3.40,10.0,102,5500,24,30,13950
# 4,2,164,audi,gas,std,four,sedan,4wd,front,99.4,176.6,66.4,54.3,2824,ohc,five,136,mpfi,3.19,3.40,8.0,115,5500,18,22,17450
# ...
